# %%
import pandas as pd

# %%
my_df = pd.read_csv('Lending-company.csv')
my_df.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cols = pd.read_csv('Lending-company.csv', usecols = ['Product'])
df_cols.head()
# Out:
#      Product
# 0  Product B
# 1  Product D
# 2  Product B
# 3  Product A
# 4  Product B

# %%
type(df_cols)
# Out:
# pandas.core.frame.DataFrame

# %%
df_single_col = pd.read_csv('Customer-Gender.csv')
df_single_col.head(10)
# Out:
#   CustomerGender
# 0         Female
# 1         Female
# 2           Male
# 3           Male
# 4         Female
# 5           Male
# 6           Male
# 7           Male
# 8           Male
# 9           Male

# %%
type(df_single_col)
# might be a single column but it's still a dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Squeeze Parameter

# %%
df_squeeze = pd.read_csv('Lending-company.csv', squeeze = True)
df_squeeze.head()
# There was a warning because the squeeze parameter only works on data with single columns
# Out:
# C:\Users\Dawodu Oluwafikayo\AppData\Local\Temp\ipykernel_9948\3183547680.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df_squeeze = pd.read_csv('Lending-company.csv', squeeze = True)
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# ...

# %%
df_usecols = pd.read_csv('Lending-company.csv', usecols = ['Product'])
df_usecols.squeeze('columns')
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
type(df_usecols.squeeze('columns'))
# It's a series now due the squeeze function, although it's apllication is different now, instead of 'squeeze = True', 
# We append .squeeze to the data to get it squeezed
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## A note on Importing data in Python

# %%
pd.read_csv('Lending-company.csv') # Direct method
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
pd.read_csv('C:/Users/Dawodu Oluwafikayo/Documents/Python Scripts/Lending-company.csv') # Copying the directory
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
import os, inspect

# %%
if '__file__' not in locals():
    fx = inspect.getframeinfo(inspect.currentframe())[0]
else:
    fx = __file__

# %%
os_dir = os.path.dirname(os.path.abspath(fx))
print(os_dir)
# Out:
# C:\Users\Dawodu Oluwafikayo\AppData\Local\Temp\ipykernel_1128

# %%
pd.read_csv(os.path.join(os_dir, "Lending-company.csv"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pd.read_csv(os.path.join(os_dir, "Lending-company.csv"))
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
